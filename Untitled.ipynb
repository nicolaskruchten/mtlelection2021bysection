# %%
import pandas as pd
import plotly.express as px

# %%
px.set_mapbox_access_token(open(".mapbox_token").read())

# %%
df = pd.read_csv("data.csv")
# Out:
# /Users/nicolas/opt/miniconda3/envs/env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning:
#
# Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
df["NOM_SECTION"] = df.apply(lambda row: str(row["DistrictID"]).zfill(3) +"-"+ str(row["Bureau"]).replace("a","").replace("b","").zfill(3), axis=1)

# %%
c = ["CODERRE Denis", "PLANTE Valérie"]
df2 = (df.query("Candidat in @c")[["NOM_SECTION", "Candidat", "Votes"]]
       .pivot_table(index="NOM_SECTION", columns="Candidat", values="Votes", aggfunc=sum)
      .reset_index()
      .rename({c[0]: "Denis Coderre", c[1]: "Valérie Plante"}, axis=1))

df2["Winner"] = df2.apply(lambda row: "Denis Coderre" if row["Denis Coderre"]>row["Valérie Plante"] else "Valérie Plante", axis=1)
df2
# Out:
# Candidat NOM_SECTION  Denis Coderre  Valérie Plante          Winner
# 0            011-001             33              66  Valérie Plante
# 1            011-002             35              61  Valérie Plante
# 2            011-003             52              60  Valérie Plante
# 3            011-004             50              45   Denis Coderre
# 4            011-005             35              76  Valérie Plante
# ...              ...            ...             ...             ...
# 3918         194-905             36              11   Denis Coderre
# 3919         194-906             73              60   Denis Coderre
# 3920         194-907            103              33   Denis Coderre
# 3921         194-908            104              50   Denis Coderre
# 3922         194-909             67              53   Denis Coderre
#
# [3923 rows x 4 columns]

# %%
df["vote_frac"] = (df.Votes / df.TotalVotes).fillna(0)

# %%
geojson = json.load(open("section-vote-2021-simple.json"))

# %%
geojson_url="https://gist.githubusercontent.com/nicolaskruchten/c3cf6b7563631fb97b735bf8c07c9713/raw/c90edcc939db1c1aee0163343bbd63a0b650eccc/section-vote-2021-simple.json"
fig = px.choropleth_mapbox(df2, geojson=geojson_url, color="Winner",
                           locations="NOM_SECTION", featureidkey="properties.NOM_SECTION",
                           center={"lat": 45.5517, "lon": -73.7073},
                           color_discrete_map={"Denis Coderre":"#e41a1c", "Valérie Plante":"#4daf4a"},
                           hover_data={"Winner": False, "NOM_SECTION": False,
                                       "Valérie Plante": True, "Denis Coderre": True, 
                                      },
                           mapbox_style="light", zoom=10, height=800, opacity=0.7)
fig.update_layout(margin={"r":0,"t":80,"l":0,"b":0}, 
                  legend=dict(orientation="h", y=1, yanchor='bottom', x=0.5, xanchor="center", title=""),
                 title=dict(text="Élections municipales de Montréal 2021", x=0.5))
fig.update_traces(marker_line_width=0.1, below='')
fig.show()

# %%
fig.write_html("index.html", include_plotlyjs="cdn")
